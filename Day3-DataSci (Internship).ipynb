# %%
#Programmer: Mahek Suhail Shaikh
#College: Keystone School Of Engineering ,Pune
#Class:TE-B
#RollNo: 29

# %%
#Pandas: structured data analysis
import pandas as pd

# %%
df=pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['marks']+0.68 #0.68 is added to every elem present in marks col
# Out:
# 0    57.45
# 1    60.45
# 2    77.56
# 3    70.34
# 4    63.96
# 5    50.23
# 6    66.02
# 7    69.01
# 8    57.43
# 9    79.34
# Name: marks, dtype: float64

# %%
df['marks']=df['marks']+0.68 #permanent modification into marks col
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  58.13   22
# 1     2     amit    TE  61.13   21
# 2     3   aniket    BE  78.24   19
# 3     4  ajinkya    TE  71.02   20
# 4     5     asha    TE  64.64   20
# 5     6   ayesha    BE  50.91   20
# 6     7     amar    BE  66.70   19
# 7     8    amita    BE  69.69   23
# 8     9     amol    TE  58.11   20
# 9    10    anmol    BE  80.02   21

# %%
df['cgpa']=df['marks']/10+1.06 #created cgpa col by manipulating the original table
df
# Out:
#    roll     name class  marks  age   cgpa
# 0     1     anil    TE  58.13   22  6.873
# 1     2     amit    TE  61.13   21  7.173
# 2     3   aniket    BE  78.24   19  8.884
# 3     4  ajinkya    TE  71.02   20  8.162
# 4     5     asha    TE  64.64   20  7.524
# 5     6   ayesha    BE  50.91   20  6.151
# 6     7     amar    BE  66.70   19  7.730
# 7     8    amita    BE  69.69   23  8.029
# 8     9     amol    TE  58.11   20  6.871
# 9    10    anmol    BE  80.02   21  9.062

# %%
df['gender']=['M','M','M','M','F','F','M','F','M','M'] #adding list of elem as col
df
# Out:
#    roll     name class  marks  age   cgpa gender
# 0     1     anil    TE  58.13   22  6.873      M
# 1     2     amit    TE  61.13   21  7.173      M
# 2     3   aniket    BE  78.24   19  8.884      M
# 3     4  ajinkya    TE  71.02   20  8.162      M
# 4     5     asha    TE  64.64   20  7.524      F
# 5     6   ayesha    BE  50.91   20  6.151      F
# 6     7     amar    BE  66.70   19  7.730      M
# 7     8    amita    BE  69.69   23  8.029      F
# 8     9     amol    TE  58.11   20  6.871      M
# 9    10    anmol    BE  80.02   21  9.062      M

# %%
#df.drop(['gender'],axis=1,inplace=True)

# %%
#Merging (joinning dataframes)
df1=pd.DataFrame ({'roll':range(1,11),'cgpa':df['marks']/10+1.06,'gender':['M','M','M','M','F','F','M','F','M','M']}
    )
# Out:
#    roll   cgpa gender
# 0     1  6.873      M
# 1     2  7.173      M
# 2     3  8.884      M
# 3     4  8.162      M
# 4     5  7.524      F
# 5     6  6.151      F
# 6     7  7.730      M
# 7     8  8.029      F
# 8     9  6.871      M
# 9    10  9.062      M

# %%
df.merge(df1,on='roll')
# Out:
#    roll     name class  marks  age  cgpa_x  cgpa_y gender
# 0     1     anil    TE  58.13   22   6.873   6.873      M
# 1     2     amit    TE  61.13   21   7.173   7.173      M
# 2     3   aniket    BE  78.24   19   8.884   8.884      M
# 3     4  ajinkya    TE  71.02   20   8.162   8.162      M
# 4     5     asha    TE  64.64   20   7.524   7.524      F
# 5     6   ayesha    BE  50.91   20   6.151   6.151      F
# 6     7     amar    BE  66.70   19   7.730   7.730      M
# 7     8    amita    BE  69.69   23   8.029   8.029      F
# 8     9     amol    TE  58.11   20   6.871   6.871      M
# 9    10    anmol    BE  80.02   21   9.062   9.062      M

# %%
#appending and concatenation of dataframes

# %%
df2=pd.read_csv('student5.csv')
df2
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df,df2])
#prob: it has just concanated the tables without making index continous
# Out:
#    roll     name class  marks  age   cgpa gender
# 0     1     anil    TE  58.13   22  6.873      M
# 1     2     amit    TE  61.13   21  7.173      M
# 2     3   aniket    BE  78.24   19  8.884      M
# 3     4  ajinkya    TE  71.02   20  8.162      M
# 4     5     asha    TE  64.64   20  7.524      F
# 5     6   ayesha    BE  50.91   20  6.151      F
# 6     7     amar    BE  66.70   19  7.730      M
# 7     8    amita    BE  69.69   23  8.029      F
# 8     9     amol    TE  58.11   20  6.871      M
# 9    10    anmol    BE  80.02   21  9.062      M
# 0     1   surbhi    TE  67.44   23    NaN    NaN
# 1     2    sujay    TE  74.12   22    NaN    NaN
# 2     3  subhash    BE  82.44   21    NaN    NaN
# 3     4   sachin    TE  59.33   21    NaN    NaN
# 4     5  shalini    TE  63.45   20    NaN    NaN

# %%
pd.concat([df,df2],ignore_index=True)
# Out:
#     roll     name class  marks  age   cgpa gender
# 0      1     anil    TE  58.13   22  6.873      M
# 1      2     amit    TE  61.13   21  7.173      M
# 2      3   aniket    BE  78.24   19  8.884      M
# 3      4  ajinkya    TE  71.02   20  8.162      M
# 4      5     asha    TE  64.64   20  7.524      F
# 5      6   ayesha    BE  50.91   20  6.151      F
# 6      7     amar    BE  66.70   19  7.730      M
# 7      8    amita    BE  69.69   23  8.029      F
# 8      9     amol    TE  58.11   20  6.871      M
# 9     10    anmol    BE  80.02   21  9.062      M
# 10     1   surbhi    TE  67.44   23    NaN    NaN
# 11     2    sujay    TE  74.12   22    NaN    NaN
# 12     3  subhash    BE  82.44   21    NaN    NaN
# 13     4   sachin    TE  59.33   21    NaN    NaN
# 14     5  shalini    TE  63.45   20    NaN    NaN

# %%
#String operations

#String functions=

# %%
help(str)
#help is function which shows all funct of str
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
df['name'].str.upper() #conversion of case->upper
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.lower() #conversion of case->lower
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df['name'].str.title() #conversion of case->title
# Out:
# 0       Anil
# 1       Amit
# 2     Aniket
# 3    Ajinkya
# 4       Asha
# 5     Ayesha
# 6       Amar
# 7      Amita
# 8       Amol
# 9      Anmol
# Name: name, dtype: object

# %%
df['name'].str.swapcase() #conversion of case->swapcase(intergange the actual case to opp case)
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.isupper()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: name, dtype: bool

# %%
df['name'].str.islower()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: name, dtype: bool

# %%
df['name'].str.isalpha() #isnum
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: name, dtype: bool

# %%
df['name'].str.find('k')
# Out:
# 0   -1
# 1   -1
# 2    3
# 3    4
# 4   -1
# 5   -1
# 6   -1
# 7   -1
# 8   -1
# 9   -1
# Name: name, dtype: int64

# %%
df['name'].str.startswith('e')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: name, dtype: bool

# %%
df['name'].str.endswith('l')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: name, dtype: bool

# %%
df['name'].str.replace('i','shaikhmahek')
# Out:
# 0       anshaikhmahekl
# 1       amshaikhmahekt
# 2     anshaikhmahekket
# 3    ajshaikhmaheknkya
# 4                 asha
# 5               ayesha
# 6                 amar
# 7      amshaikhmahekta
# 8                 amol
# 9                anmol
# Name: name, dtype: object

# %%
df['name'].str.repeat(4)
# Out:
# 0                anilanilanilanil
# 1                amitamitamitamit
# 2        aniketaniketaniketaniket
# 3    ajinkyaajinkyaajinkyaajinkya
# 4                ashaashaashaasha
# 5        ayeshaayeshaayeshaayesha
# 6                amaramaramaramar
# 7            amitaamitaamitaamita
# 8                amolamolamolamol
# 9            anmolanmolanmolanmol
# Name: name, dtype: object

# %%
##Group Functions
grp=df.groupby('class')
grp.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
grp=df.groupby('age')
grp.groups
# Out:
# {19: [2, 6], 20: [3, 4, 5, 8], 21: [1, 9], 22: [0], 23: [7]}

# %%
gk = df.groupby('name')
gk

# %%
gr.groups

# %%
#gr.min()
#gr.max()
#gr.sum()
#gr.median()
#gr['marks'].sum()

# %%
#Bool Filters
df['marks']>60
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
mask=df['marks']>60
df[mask]
#mask:true vals are fetched and rest is discarded
# Out:
#    roll     name class  marks  age   cgpa gender
# 1     2     amit    TE  61.13   21  7.173      M
# 2     3   aniket    BE  78.24   19  8.884      M
# 3     4  ajinkya    TE  71.02   20  8.162      M
# 4     5     asha    TE  64.64   20  7.524      F
# 6     7     amar    BE  66.70   19  7.730      M
# 7     8    amita    BE  69.69   23  8.029      F
# 9    10    anmol    BE  80.02   21  9.062      M

# %%
df[df['marks']>60]
# Out:
#    roll     name class  marks  age   cgpa gender
# 1     2     amit    TE  61.13   21  7.173      M
# 2     3   aniket    BE  78.24   19  8.884      M
# 3     4  ajinkya    TE  71.02   20  8.162      M
# 4     5     asha    TE  64.64   20  7.524      F
# 6     7     amar    BE  66.70   19  7.730      M
# 7     8    amita    BE  69.69   23  8.029      F
# 9    10    anmol    BE  80.02   21  9.062      M

# %%
x=df[(df['marks']>60) & (df['class']=='TE')]
x
# Out:
#    roll     name class  marks  age   cgpa gender
# 1     2     amit    TE  61.13   21  7.173      M
# 3     4  ajinkya    TE  71.02   20  8.162      M
# 4     5     asha    TE  64.64   20  7.524      F

# %%
df[df['name'].str.startswith('am')]
# Out:
#    roll   name class  marks  age   cgpa gender
# 1     2   amit    TE  61.13   21  7.173      M
# 6     7   amar    BE  66.70   19  7.730      M
# 7     8  amita    BE  69.69   23  8.029      F
# 8     9   amol    TE  58.11   20  6.871      M

# %%
#EXPORTING THE DATA
x
# Out:
#    roll     name class  marks  age   cgpa gender
# 1     2     amit    TE  61.13   21  7.173      M
# 3     4  ajinkya    TE  71.02   20  8.162      M
# 4     5     asha    TE  64.64   20  7.524      F

# %%
x.to_csv('output.csv',index=False)
#create file name output
