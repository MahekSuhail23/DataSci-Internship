# %%
#Programmer: Mahek Suhail Shaikh
#College: Keystone School Of Engineering ,Pune
#Class:TE-B
#RollNo: 29

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp

# %%
#transformation= conversion raw data from  to other
#methods-> data encoding
# DATA ENCODING->categorical val to int format->fed to machine for predictions(improve)
#one hot ,effecr,binary,label/ordinal,base-n,hash,target enchodings

# %%
df=pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
#Scikit-Learn, also known as sklearn is a python library
#to implement machine learning models and statistical modelling.
#Through scikit-learn, we can implement various machine learning models for 
#regression, classification, clustering, and statistical tools for analyzing these models.


#label/ordinal encoding -order is considered(Str)

# %%
#importing the class
from sklearn.preprocessing import LabelEncoder
#creating obj of sklearn
le=LabelEncoder()

# %%
df['name']=le.fit_transform(df['name'])
df
#num are assigned with order (alphabetical) and the dtype is changed to int
#fit_tranform=fetch and transform
# Out:
#    roll  name class  marks  age
# 0     1     6    TE  56.77   22
# 1     2     2    TE  59.77   21
# 2     3     5    BE  76.88   19
# 3     4     0    TE  69.66   20
# 4     5     8    TE  63.28   20
# 5     6     9    BE  49.55   20
# 6     7     1    BE  65.34   19
# 7     8     3    BE  68.33   23
# 8     9     4    TE  56.75   20
# 9    10     7    BE  78.66   21

# %%
#if we run it again and again you will get 0000 since it is in str->int->int

# %%
df.dtypes
# Out:
# roll       int64
# name       int32
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
le.classes_
# Out:
# array(['ajinkya', 'amar', 'amit', 'amita', 'amol', 'aniket', 'anil',
#        'anmol', 'asha', 'ayesha'], dtype=object)

# %%
new=3
le.inverse_transform([new])
# Out:
# array(['amita'], dtype=object)

# %%
df['name']=le.inverse_transform(df['name'])
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['name']=le.fit_transform(df['name'])
df
# Out:
#    roll  name class  marks  age
# 0     1     6    TE  56.77   22
# 1     2     2    TE  59.77   21
# 2     3     5    BE  76.88   19
# 3     4     0    TE  69.66   20
# 4     5     8    TE  63.28   20
# 5     6     9    BE  49.55   20
# 6     7     1    BE  65.34   19
# 7     8     3    BE  68.33   23
# 8     9     4    TE  56.75   20
# 9    10     7    BE  78.66   21

# %%
#2: ONE HOT ENCODING
pd.get_dummies(df)
#info is retained and preserved, highly recomm
# Out:
#    roll  name  marks  age  class_BE  class_TE
# 0     1     6  56.77   22         0         1
# 1     2     2  59.77   21         0         1
# 2     3     5  76.88   19         1         0
# 3     4     0  69.66   20         0         1
# 4     5     8  63.28   20         0         1
# 5     6     9  49.55   20         1         0
# 6     7     1  65.34   19         1         0
# 7     8     3  68.33   23         1         0
# 8     9     4  56.75   20         0         1
# 9    10     7  78.66   21         1         0

# %%
df.dtypes
# Out:
# roll       int64
# name       int32
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
#3: BINARIZATION
#covert the CONTINOUS data into binary format
df=pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['marks']
# Out:
# 0    56.77
# 1    59.77
# 2    76.88
# 3    69.66
# 4    63.28
# 5    49.55
# 6    65.34
# 7    68.33
# 8    56.75
# 9    78.66
# Name: marks, dtype: float64

# %%
#threshold value= if vals above Firstclass
from sklearn.preprocessing import Binarizer
bin=Binarizer(threshold=65)

#If someone have 60 marks, it will be 0 and 60+ marks= 1?

# %%
df['FirstClass']=bin.fit_transform(df[['marks']])
df
# Out:
#    roll     name class  marks  age  FirstClass
# 0     1     anil    TE  56.77   22         0.0
# 1     2     amit    TE  59.77   21         0.0
# 2     3   aniket    BE  76.88   19         1.0
# 3     4  ajinkya    TE  69.66   20         1.0
# 4     5     asha    TE  63.28   20         0.0
# 5     6   ayesha    BE  49.55   20         0.0
# 6     7     amar    BE  65.34   19         1.0
# 7     8    amita    BE  68.33   23         1.0
# 8     9     amol    TE  56.75   20         0.0
# 9    10    anmol    BE  78.66   21         1.0

# %%
df.dtypes
# Out:
# roll            int64
# name           object
# class          object
# marks         float64
# age             int64
# FirstClass    float64
# dtype: object

# %%
df['FirstClass']=df['FirstClass'].astype(int)
df
# Out:
#    roll     name class  marks  age  FirstClass
# 0     1     anil    TE  56.77   22           0
# 1     2     amit    TE  59.77   21           0
# 2     3   aniket    BE  76.88   19           1
# 3     4  ajinkya    TE  69.66   20           1
# 4     5     asha    TE  63.28   20           0
# 5     6   ayesha    BE  49.55   20           0
# 6     7     amar    BE  65.34   19           1
# 7     8    amita    BE  68.33   23           1
# 8     9     amol    TE  56.75   20           0
# 9    10    anmol    BE  78.66   21           1

# %%
#Feature Scaling-unit conversion,scale or spread same
#1.Normalization =MinMaxScaler ,range 0 to 1
#2.Standardization

# %%
x=np.array([24,29,39,28,6,2,87,56,33])

# %%
def norm(a):
    n1=(a-a.min())/(a.max()-a.min())
    return n1
norm(x)
# Out:
# array([0.25882353, 0.31764706, 0.43529412, 0.30588235, 0.04705882,
#        0.        , 1.        , 0.63529412, 0.36470588])

# %%
nx=norm(x)

# %%
mp.figure(figsize=(16,9))

mp.subplot(1,2,1)
mp.title('Actual Data')
mp.plot(x)

mp.subplot(1,2,2)
mp.title('Normalized data')
mp.plot(nx)

#beacuse the max value is 1 and min value is 0 the y axis is then equally divided in range 0-1

# %%
y=np.array([387,543,876,223,124,765,987,985])

# %%
ny=norm(y)
ny
# Out:
# array([0.30475087, 0.48551564, 0.87137891, 0.11471611, 0.        ,
#        0.74275782, 1.        , 0.9976825 ])

# %%
df1=pd.read_csv('Social_Network_Ads.csv')
df1
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
x=df1[['Age','EstimatedSalary']]
y=df1['Purchased']

# %%
mp.xlabel('age')
mp.ylabel('salary')
mp.grid()
mp.scatter(x['Age'],x['EstimatedSalary'],c=y)

#scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)

# %%
x.describe()
# Out:
#               Age  EstimatedSalary
# count  400.000000       400.000000
# mean    37.655000     69742.500000
# std     10.482877     34096.960282
# min     18.000000     15000.000000
# 25%     29.750000     43000.000000
# 50%     37.000000     70000.000000
# 75%     46.000000     88000.000000
# max     60.000000    150000.000000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
#x_scaled is array
x_scaled=scaler.fit_transform(x)
type(x_scaled)
# Out:
# numpy.ndarray

# %%
x_new=pd.DataFrame(x_scaled,columns=x.columns)
x_new
# Out:
#           Age  EstimatedSalary
# 0    0.023810         0.029630
# 1    0.404762         0.037037
# 2    0.190476         0.207407
# 3    0.214286         0.311111
# 4    0.023810         0.451852
# ..        ...              ...
# 395  0.666667         0.192593
# 396  0.785714         0.059259
# 397  0.761905         0.037037
# 398  0.428571         0.133333
# 399  0.738095         0.155556
#
# [400 rows x 2 columns]

# %%
x_new.describe()
# Out:
#               Age  EstimatedSalary
# count  400.000000       400.000000
# mean     0.467976         0.405500
# std      0.249592         0.252570
# min      0.000000         0.000000
# 25%      0.279762         0.207407
# 50%      0.452381         0.407407
# 75%      0.666667         0.540741
# max      1.000000         1.000000

# %%
mp.figure(figsize=(16,9))
mp.subplot(1,2,1)
mp.title('Acual Data')
mp.xlabel('age')
mp.ylabel('salary')
mp.grid()
mp.scatter(x['Age'],x['EstimatedSalary'],c=y)

mp.subplot(1,2,2)
mp.title('Normalize Data')
mp.xlabel('age')
mp.ylabel('salary')
mp.grid()
mp.scatter(x_new['Age'],x_new['EstimatedSalary'],c=y)

# %%
#import seaborn as sns
#fig,axes=mp.subplots(1,2,figsize=(16,9))
#sns.jointplot(x='Age',y='EstimatedSalary',data=df1,hue='Purchased',ax=axes[0])

#sns.jointplot(x='Age',y='EstimatedSalary',data=x_new,hue=y,ax=axes[1])
#mp.show()
